# %%
if __name__ == '__main__':
    print("Hello, World!")
# Out:
# Hello, World!

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a+b)
    print(a-b)
    print(a*b)
# Out:
# 12
# 15
# 27
# -3
# 180

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)
# Out:
# 6
# 2
# 3
# 3.0

# %%
if __name__ == '__main__':
    n = int(input())
    for i in range(n):
        print(i*i)
# Out:
# 4
# 0
# 1
# 4
# 9

# %%
def is_leap(year):
    leap = False

    # Write your logic
    if (year%400==0) or (year%4==0 and year%100!=0):
        leap=True

    return leap
print(is_leap(2000))
# Out:
# True

# %%
if __name__ == '__main__':
    n = int(input())
    res = ""
    for i in range(1, n + 1):
        res += str(i)
    print(res)
# Out:
# 4
# 1234
